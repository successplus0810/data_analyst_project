# %%
import json
import pandas as pd
import snowflake.connector as sf
import os
import xlwings as xw
from xlwings.constants import DeleteShiftDirection
import datetime
import math
pd.options.mode.chained_assignment = None
pd.options.display.float_format = '{:.0f}'.format
from pywintypes import com_error
import win32com.client as win32

###### Analyst fill
folder_name = '202202'

###############################################
config_coles = r"config.json"

file_sql_claimpack = r"claim_pack.sql"
file_sql_summ_state = r"summarizer_state.sql"
file_sql_summ = r"summarizer.sql"
file_sql_cd_ref = r"cd_ref.sql"
file_sql_cd_check_cole_online = r"cd_check_cole_online.sql"
file_sql_ven_stop_trading = r"check_ven_stop_trading.sql"
file_sql_cd_check_prgx = r"cd_check_prgx.sql"
file_sql_cd_ref_listagg = r"cd_ref_listagg.sql"
file_sql_cd_ref_listagg_item = r"cd_ref_listagg_item.sql"

path_check_list = fr"D:\\python\\claim_pack_ce\\claim_qty\\{folder_name}\\checklist.xlsx"
path_check_list_promo = fr"D:\\python\\claim_pack_ce\\claim_qty\\{folder_name}\\check_list_promo.xlsx"

path_export = fr"D:\\python\\claim_pack_ce\\claim_qty\\{folder_name}\\"
path_excel = r"CE_SCAN_Vendorname_Analyst_Date.xlsx"
path_dna = r"DNA.xlsx"

iconPath_email = r"C:\Program Files\Microsoft Office\root\Office16\OUTLOOK.EXE"
iconPath_excel = r"C:\Program Files\Microsoft Office\root\Office16\EXCEL.EXE"


os.chdir('D:\\python\\claim_pack_ce')

def set_up(config):
    """Set up connection to SnowFlake"""
    config = json.loads(open(config).read())
    account = config['snowflake']['account']
    user = config['snowflake']['user']
    warehouse = config['snowflake']['warehouse']
    role = config['snowflake']['role']
    database = config['snowflake']['database']
    schema = config['snowflake']['schema']
    password = config['snowflake']['password']
    auth = config['snowflake']['authenticator']

    conn = sf.connect(user=user, password=password, account=account, authenticator=auth,
                      warehouse=warehouse, role=role, database=database, schema=schema)

    cursor = conn.cursor()
    return cursor
def connect_sql(cursor,file_sql,item_code=0,var_1=0,var_2=0,var_3=0,var_4=0,var_5=0,var_6 = 0):
    try:
        # cursor.execute((open(file_sql).read()))
        cursor.execute(open(file_sql).read().format(item_code,var_1,var_2,var_3,var_4,var_5,var_6))
        all_rows = cursor.fetchall()
        field_names = [i[0] for i in cursor.description]
    finally:
        pass
        # conn.close()
    df = pd.DataFrame(all_rows)
    try:
        df.columns = field_names
    except ValueError:
        return pd.DataFrame(columns=field_names)
    return df

def convert_to_input_sql(num_list):
    num_list_final = ''
    # print('SUPP LIST',supp_num_list)
    for num_list in num_list:
        num_list_final = num_list_final + "'" + str(num_list) + "',"
    return num_list_final[:-1]

def convert_to_input_function(num_list):
    num_list_final = ''
    # print('SUPP LIST',supp_num_list)
    for num_list in num_list:
        num_list_final = num_list_final + str(num_list) + ','
    return num_list_final[:-1]

def get_info(df_splited):
    supp_num_list = list(df_splited['SUPPLIER'].drop_duplicates())
    item_list = list(df_splited['SKU_ID'].drop_duplicates())

    supp_num_list_final = convert_to_input_sql(num_list = supp_num_list)
    item_list_final = convert_to_input_sql(num_list = item_list)
    item_input_function = convert_to_input_function(num_list = item_list)
    return supp_num_list_final,item_list_final,item_input_function

def writer_excel(data,remove,number_sheet,path_export_final):
    # data = list_data, remove = list_remove,number_sheet= str(index_promo)+'_'+str(gst),path_export_final=path_export_final
    #select sheet
    sheet_df_mapping = {number_sheet: data}
    sheet_df_remove  = {number_sheet: remove}
    # Open Excel in background
    with xw.App(visible=False) as app:
        wb = app.books.open(path_export_final)
        # List of current worksheet names
        current_sheets = [sheet.name for sheet in wb.sheets]
        # Iterate over sheet/df mapping
        # If sheet already exist, overwrite current cotent. Else, add new sheet
        for sheet_name in sheet_df_mapping.keys():
            if sheet_name in current_sheets:
                for df_data in data :
                    wb.sheets(sheet_name).range(df_data['cell_export']).options(index=False,header=False,numbers = int).value = df_data['df']
            else:
                'Name of sheet cannot be found in Excel file, please check again'
        for sheet_name in sheet_df_remove.keys():
            if sheet_name in current_sheets:
                for df_remove in remove :
                    # wb.sheets(sheet_name).range(df_cell['cell_export']).options(index=False,header=False).value = df_cell['df']
                    length_start = df_remove['length_start'] + df_remove['count_df']
                    range_length_to_remove = str(length_start)+':'+ str(df_remove['length_end'])
                    wb.sheets(sheet_name).range(range_length_to_remove).api.Delete(DeleteShiftDirection.xlShiftUp)
            else:
                'Name of sheet cannot be found in Excel file, please check again'
        wb.save(path_export_final)
    return None

def fill_summary_sheet(summary_index_list,path_export_final):
    print('Start fill summary sheet')
    with xw.App(visible=False) as app:
        wb_from = app.books.open(path_export_final)
        summary_index = 1
        for index in summary_index_list:
            wb_from.sheets['Vendor Summary'].range('B'+str(summary_index+10)).value = index
            summary_index += 1
        length_start = summary_index + 10
        range_length_to_remove = str(length_start)+':'+ str(30)
        wb_from.sheets('Vendor Summary').range(range_length_to_remove).api.Delete(DeleteShiftDirection.xlShiftUp)         
        wb_from.save(path_export_final)
    return 'Done fill summary sheet' 

def create_worksheet(index_promo,gst,path_export_final):
    # Open Excel in background
    with xw.App(visible=False) as app:
        if index_promo == 1:
            wb_from = app.books.open(path_excel)
        else :
            wb_from = app.books.open(path_export_final)
        ws_from = wb_from.sheets['template']
        ws_from.copy(before=ws_from, name=str(index_promo)+'_'+str(gst))
        wb_from.save(path_export_final)
    return 'Done create worksheet'     

def remove_sheet_change_xlsb(sheet_name,path_export_final,path_export_final_xlsb):
    print('Start delete sheet & change to xlsb')
    with xw.App(visible=False) as app:
        wb = app.books.open(path_export_final)                
        wb.sheets[sheet_name].delete()
        wb.save(path_export_final_xlsb)
    try:
        os.remove(path_export_final)
    except Exception as e:
        print(e)
    return print('Done delete sheet & change to xlsb')

# item_code=0,var_1=0,var_2=0,var_3=0,var_4=0

def df_sales_data(cursor, item_list_dict_gsted,start_date,end_date,pmt_id_temp,classify_state):
    i = 0
    print(classify_state)
    if classify_state == 'TO QA_STATE' :
        for key,value in item_list_dict_gsted.items():
            print(key,value)
            item , state = key
            df_each_item = connect_sql(cursor = cursor,file_sql = file_sql_summ_state ,item_code = item,var_1 =pmt_id_temp , var_2 = start_date,var_3=end_date,var_4=value[0],var_5=value[1],var_6=state)
            if i == 0:
                df_merge = df_each_item
            else :
                df_merge = pd.concat([df_merge, df_each_item], ignore_index=True)
            i+=1
        df_merge['ELI_CLAIM'] = df_merge.RQTY_PROMO * df_merge.SCAN_RATE
        df_merge= df_merge.sort_values(by=['RSKU_ID','RDAY_DT','RSTATE'], ascending=True).reset_index(drop=True)
    else:
        for key,value in item_list_dict_gsted.items():
            print(key,value)
            df_each_item = connect_sql(cursor = cursor,file_sql = file_sql_summ ,item_code = key,var_1 =pmt_id_temp , var_2 = start_date,var_3=end_date,var_4=value[0],var_5=value[1])
            if i == 0:
                df_merge = df_each_item
            else :
                df_merge = pd.concat([df_merge, df_each_item], ignore_index=True)
            i+=1
        df_merge['ELI_CLAIM'] = df_merge.RQTY_PROMO * df_merge.SCAN_RATE
        df_merge= df_merge.sort_values(by=['RSKU_ID','RDAY_DT','RSTATE'], ascending=True).reset_index(drop=True)
    # i = 0
    # for key,value in item_list_dict_gsted.items():
    #     item , state = key
    #     df_each_item = connect_sql(cursor = cursor,file_sql = file_sql_summ_state ,item_code = item,var_1 =pmt_id_temp , var_2 = start_date,var_3=end_date,var_4=value[0],var_5=value[1],var_6=state)
    #     if i == 0:
    #         df_merge = df_each_item
    #     else :
    #         df_merge = pd.concat([df_merge, df_each_item], ignore_index=True)
    #     i+=1
    # df_merge['ELI_CLAIM'] = df_merge.RQTY_PROMO * df_merge.SCAN_RATE
    # df_merge = df_merge.sort_values(by=['RSKU_ID','RDAY_DT','RSTATE']).reset_index(drop=True)
    return df_merge

def product_state_summary(df,df_ref):
    print('Start product_state_summary')
    list_data = []
    list_remove = []
    # Find distict item_code and state
    # writer_excel(df,cell_export,length_start,count_df,length_end,number_sheet,path_export_final)
    df_temp =df.drop_duplicates(['RSKU_ID','RITEM_DESC','RSTATE'])[['RSKU_ID','RITEM_DESC','RSTATE']]
    df_temp_2 = pd.merge(df_temp,df_ref,left_on=['RSKU_ID','RSTATE'],right_on=['ITEM_IDNT','CLM_STATE'], how='left')
    print('df refffffffffff',df_ref)
    df_final = df_temp_2[['RSKU_ID','RITEM_DESC','RSTATE','REF_NUM','CLM_QTY','CLM_RATE','CLM_PRODUCT']]
    df_sku_desc = df_final[['RSKU_ID','RITEM_DESC']]
    df_state = df_final[['RSTATE']]
    df_ref = df_final[['REF_NUM','CLM_QTY','CLM_RATE','CLM_PRODUCT']]
    df_ref.insert(1,"REF_DESC",'')
    # Calculate number of rows
    number_rows_state = len(df_ref)
    dict_data_sku = {'df':df_sku_desc,'cell_export':'B121'}
    dict_data_state = {'df':df_state,'cell_export':'E121'}
    dict_data_remove = {'df':df_ref,'cell_export':'M121'}
    dict_remove = {'count_df':number_rows_state,'length_start':121,'length_end':601}
    list_data.append(dict_data_sku)
    list_data.append(dict_data_state)
    list_data.append(dict_data_remove)
    list_remove.append(dict_remove)
    print('Done product_state_summary')
    return list_data,list_remove

def product_summary(df,df_item_ref):
    print('Start product_summary')
    list_data = []
    list_remove = []
    df_product =df.drop_duplicates(['RSKU_ID','RITEM_DESC'])[['RSKU_ID','RITEM_DESC']]
    print(df_product)
    df_temp = pd.merge(df_product,df_item_ref,left_on=['RSKU_ID'],right_on=['ITEM_IDNT'], how='left')
    print(df_item_ref)
    print(df_temp)
    # df_final = df_temp[['RSKU_ID','RITEM_DESC','REF_NUM']]
    df_product_1 = df_temp[['RSKU_ID','RITEM_DESC']]
    df_ref_1 = df_temp[['REF_NUM','CLM_QTY','CLM_RATE','CLM_PRODUCT']]
    df_ref_1.insert(1,"REF_DESC",'')
    number_rows_sales = len(df_product)
    # writer_excel(df = df_product,path_export_final = path_export_final, cell_export = 'B20',number_sheet = number_sheet,length_start=20 , count_df=number_rows_sales, length_end=116)
    dict_data_sku = {'df':df_product_1,'cell_export':'B20'}
    dict_data_ref = {'df':df_ref_1,'cell_export':'L20'}
    dict_remove = {'count_df':number_rows_sales,'length_start':20,'length_end':116}
    list_data.append(dict_data_sku)
    list_data.append(dict_data_ref)
    list_remove.append(dict_remove)
    print('Done product_summary')
    return list_data , list_remove

def cd_ref(prmt_id,cursor,file_sql,item_code,df_sales,file_sql_2, file_sql_3):
    print('Start cd ref')
    list_data = []
    list_remove = []
    print('item_code',item_code)
    print('prmt_id',prmt_id)
    df_ref = connect_sql(cursor=cursor,file_sql = file_sql ,item_code = item_code,var_1 = prmt_id)
        # df_ref= pd.DataFrame(columns=['CLM_REF_NUM','CLM_PRODUCT'])---------
    try:
        df_ref_groupby = df_ref.groupby('CLM_REF_NUM').agg({'CLM_PRODUCT':'sum'}).sort_values(by='CLM_PRODUCT', ascending=True).reset_index()
    except:
        df_ref_groupby = pd.DataFrame(columns=['CLM_REF_NUM','CLM_PRODUCT'])
    print('df_ref_groupby:\n',df_ref_groupby)
    df_sales_daily = pd.concat([df_sales, df_ref_groupby], axis=1)
    print('Done cd ref')
    print('start state ref')
    df_state_ref = connect_sql(cursor=cursor,file_sql = file_sql_2 ,item_code = item_code,var_1 = prmt_id)
    if df_state_ref.empty:
        df_state_ref = pd.DataFrame(columns=['ITEM_IDNT','CLM_STATE','CLM_QTY','CLM_RATE','CLM_PRODUCT','REF_NUM'])
    print(df_state_ref)
    print('done state ref')
    print('start item ref')
    df_item_ref = connect_sql(cursor=cursor,file_sql = file_sql_3 ,item_code = item_code,var_1 = prmt_id)
    if df_item_ref.empty:
        df_item_ref = pd.DataFrame(columns=['ITEM_IDNT','CLM_QTY','CLM_RATE','CLM_PRODUCT','REF_NUM'])
    print(df_item_ref)
    print('done item ref')
    # writer_excel(df = df_sales, cell_export = 'B174',number_sheet= str(index_promo)+'_'+str(gst),length_start=174 ,count_df=len(df_sales), length_end=10174,path_export_final=path_export_final)
    dict_data = {'df':df_sales_daily,'cell_export':'B606'}
    dict_remove = {'count_df':len(df_sales),'length_start':606,'length_end':20606}
    list_data.append(dict_data)
    list_remove.append(dict_remove)
    return df_item_ref,df_state_ref,df_ref,df_sales_daily,list_data,list_remove

def insert_attachments(sheet_name,file_path_excel,file_path_email,path_export_final):  
    print('Start insert email and excel')
    print(file_path_excel)
    print(file_path_email)
    xl = win32.gencache.EnsureDispatch('Excel.Application')
    wb = xl.Workbooks.Open(path_export_final, UpdateLinks = True)
    ws = wb.Worksheets(sheet_name)
    try:
        excel_name = file_path_excel.split('/')[-1][0:10]
    except:
        excel_name ='excel'
    try:
        email_name = file_path_email.split('/')[-1][0:10]
    except:
        email_name = 'email'
    obj = ws.OLEObjects()
    xl.DisplayAlerts = False
    #xl.AskToUpdateLinks = False
    try:
        obj.Add(ClassType=None, Filename=file_path_excel, Link=False, DisplayAsIcon=True, IconFileName=iconPath_excel,IconIndex=0, IconLabel = excel_name , Left=ws.Range("J8").Left, Top=ws.Range("J8").Top, Width=50, Height=50)
        print(f'Successfully insert excel file in sheet {sheet_name}')
    except com_error:
        print(f'Cannot insert excel file in sheet {sheet_name}')
        pass
    try:
        obj.Add(ClassType=None, Filename=file_path_email, Link=False, DisplayAsIcon=True, IconFileName=iconPath_email,IconIndex=0, IconLabel = email_name , Left= ws.Range("L8").Left, Top=ws.Range("L8").Top, Width=50, Height=50)
        print(f'Successfully insert email file in sheet {sheet_name}')
    except com_error:
        print(f'Cannot insert email file in sheet {sheet_name}')
        pass
    xl.DisplayAlerts = True
    #xl.AskToUpdateLinks = True
    wb.Save()
    wb.Close()
    # xl.Application.Quit()
    #del xl
    print('Done insert email and excel')
    return None
  
def main():
    cursor = set_up(config = config_coles)
    df_raw = connect_sql(cursor = cursor,file_sql = file_sql_claimpack)
    df_unique_supp = df_raw[['SUPPLIER','PRMTN_COMP_IDNT']].drop_duplicates().values.tolist()
    # Read DNA file
    df_dna = pd.read_excel(path_dna,sheet_name='DNA')
    list_dna = df_dna['DNA'].drop_duplicates().values.tolist()
    # Read vendor stop trading
    df_ven_stop_trading = connect_sql(cursor = cursor,file_sql = file_sql_ven_stop_trading)
    list_ven_stop_trading = df_ven_stop_trading['RMS_NUM'].drop_duplicates().values.tolist()
    # Create dictionary with supp_num key and list of promo_ids
    dict_sup_pro = {}
    i=0
    for list_sup in df_unique_supp:
        if i == 0:
            dict_sup_pro[list_sup[0]] = [list_sup[1]]
        else:
            if list_sup[0] in dict_sup_pro.keys():
                dict_sup_pro[list_sup[0]].append(list_sup[1])
            else:
                dict_sup_pro[list_sup[0]] = [list_sup[1]]
        i+=1
    print(dict_sup_pro)
    # return 0
    j = 0
    for supp_num,list_pmt_id in dict_sup_pro.items():
        supp_num_convert = convert_to_input_sql(num_list=[supp_num])
        # To classify Check_column
        for pmt_id in list_pmt_id:
            df_splited = df_raw[(df_raw['SUPPLIER'] == supp_num) & (df_raw['PRMTN_COMP_IDNT'] == pmt_id)]   
            print(df_splited)
            # Classify Check_column
            if math.isnan(supp_num):
                df_splited['CHECK_COLUMN'] = 'NULL SUPPLIER'
            else:
                if (int(supp_num) in list_dna) or math.isnan(supp_num):
                    df_splited['CHECK_COLUMN'] = 'DNA'
                elif str(supp_num_convert) in list_ven_stop_trading:
                    df_splited['CHECK_COLUMN'] = 'VENDOR STOP TRADING'
                elif df_splited['ELI_EXCLUDE'].unique()[0] > -100 :
                    df_splited['CHECK_COLUMN'] = 'ELI_EXCLUDE < 100'
                # elif df_splited['ELI2'].sum() <= 0 :
                #     df_splited['CHECK_COLUMN'] = 'ELI2 <= 0'
                # elif df_splited['ELI3'].sum() <= 0 :
                #     df_splited['CHECK_COLUMN'] = 'ELI3 <= 0'
                # elif '1' not in df_splited['OVERLAP_PROMO'].unique().astype(str): 
                #     df_splited['CHECK_COLUMN'] = 'OVERLAP'
                elif df_splited['CLM_QTY'].sum() < 0 :
                    df_splited['CHECK_COLUMN'] = 'CLM_QTY <= 0'
                elif df_splited['CHECK_PRGX'].unique()[0] == 'YES':
                    df_splited['CHECK_COLUMN'] = 'PRGX RAISED'
                else:
                    if df_splited[['SKU_ID','CLM_RATE','PRM_PRICE']].drop_duplicates()['SKU_ID'].count() == df_splited['SKU_ID'].drop_duplicates().count():
                    # if df_splited[['SKU_ID','CLM_RATE']].drop_duplicates().count()[0] == df_splited['SKU_ID'].drop_duplicates().count():
                        df_splited['CHECK_COLUMN'] = 'TO QA_NATIONAL'
                    else:
                        df_splited['CHECK_COLUMN'] = 'TO QA_STATE'
            if j  == 0:
                df_raw_check = df_splited
            else:
                df_raw_check = pd.concat([df_raw_check, df_splited], ignore_index=True)
            j+=1
    #Export checklist
    df_raw_check.to_excel(path_check_list,index=False)
    # return 0
    ###############################################################
    error_list =[]
    time_start = datetime.datetime.now()
    # Filter df_splited with condition , keep TO QA and PRGX
    # df_raw_filter = df_raw_check[(df_raw_check['CHECK_COLUMN'] == 'TO QA_NATIONAL') | (df_raw_check['CHECK_COLUMN'] == 'TO QA_STATE')] 
    df_raw_filter = df_raw_check[(df_raw_check['CHECK_COLUMN'] == 'TO QA_STATE')] 
    df_unique_supp_filter = df_raw_filter[['SUPPLIER','PRMTN_COMP_IDNT','CHECK_COLUMN']].drop_duplicates().values.tolist()
    # Create dictionary with supp_num key and list of promo_ids after filter conditions, keep check again and to QA
    dict_sup_pro_filter = {}
    j=0
    for list_sup in df_unique_supp_filter:
        if j == 0:
            dict_sup_pro_filter[list_sup[0]] = [[list_sup[1]] + [list_sup[2]]]
        else:
            if list_sup[0] in dict_sup_pro_filter.keys():
                dict_sup_pro_filter[list_sup[0]].append([list_sup[1]] + [list_sup[2]])
            else:
                dict_sup_pro_filter[list_sup[0]] = [[list_sup[1]] + [list_sup[2]]]
        j+=1

    check_list_promo_index = 1
    for supp_num,list_pmt_id in dict_sup_pro_filter.items():
        index_promo=1
        # summary_index = 1
        summary_index_list = []
        for pmt_id in list_pmt_id:
            print(f'-------------------------------------------------------{pmt_id[0]}------------------------------------------------------------------')
            classify_state = pmt_id[1]
            check_list_promo = []
            df_splited_filter = df_raw_filter[(df_raw_filter['SUPPLIER'] == supp_num) & (df_raw_filter['PRMTN_COMP_IDNT'] == pmt_id[0])] 
            # get some important variable
            supp_num_list_final,item_list_final,item_input_function = get_info(df_splited = df_splited_filter)
            try:
                supp_desc = df_splited_filter['SUPP_DESC'].unique()[0].replace("/","").replace(":","")
            except:
                supp_desc = 'SUPP_DESC'
            print('supp_desc',supp_desc)
            gst = df_splited_filter['CML_COST_GST_RATE_PCT'].unique()[0]
            try:
                dept = df_splited_filter[df_splited_filter['DEPT_IDNT'].notnull()]['DEPT_IDNT'].drop_duplicates().reset_index(drop=True)[0]
            except:
                dept = 0.0
            prmt_id = df_splited_filter['PRMTN_COMP_IDNT'].unique()[0]
            print(prmt_id)
            prmt_name = df_splited_filter['PRMTN_COMP_NAME'].unique()[0] 
            try:
                paf_loc = df_splited_filter['PAF_LOCATION'].unique()[0]
            except Exception :
                paf_loc = '0'
            try:
                email_loc = df_splited_filter['EMAIL'].unique()[0]
            except Exception :
                email_loc = '0'
            vendor_num = df_splited_filter['VENDOR_NUM'].unique()[0] 
            clm_start = df_splited_filter['SLS_START'].min()
            clm_end = df_splited_filter['SLS_END'].max()
            #create path for excel and path_xlsb for excel
            path_export_final = path_export+'CE_SCAN_'+supp_desc+'_Analyst_date.xlsx'
            path_export_final_xlsb = path_export+'CE_SCAN_'+supp_desc+'_Analyst_date_'+str(supp_num)+'.xlsb'
            create_worksheet(index_promo=index_promo,gst=gst,path_export_final=path_export_final)
            if classify_state == 'TO QA_NATIONAL' :
                df_splited_filter = df_splited_filter[['SKU_ID','PRM_PRICE','CLM_RATE']].drop_duplicates()
                df_splited_filter = df_splited_filter.groupby(by = ['PRM_PRICE','CLM_RATE'])['SKU_ID'].agg(list).to_frame().reset_index()
                df_splited_filter['SKU_ID'] = df_splited_filter['SKU_ID'].apply(lambda x : convert_to_input_function(x))
                item_list_dict = df_splited_filter.set_index('SKU_ID')[['PRM_PRICE','CLM_RATE']].to_dict('index')
                for key,value in item_list_dict.items():
                    item_list_dict[key] = [item_list_dict[key]['PRM_PRICE']] + [item_list_dict[key]['CLM_RATE']] 
                print(item_list_dict)
            else:
                df_splited_filter = df_splited_filter[['SKU_ID','STATE','PRM_PRICE','CLM_RATE']].drop_duplicates()
                df_splited_filter = df_splited_filter.groupby(by = ['PRM_PRICE','CLM_RATE','STATE'])['SKU_ID'].agg(list).to_frame().reset_index()
                df_splited_filter['SKU_ID'] = df_splited_filter['SKU_ID'].apply(lambda x : convert_to_input_function(x))
                df_splited_filter = df_splited_filter.groupby(by = ['PRM_PRICE','CLM_RATE','SKU_ID'])['STATE'].agg(list).to_frame().reset_index()
                df_splited_filter['STATE'] = df_splited_filter['STATE'].apply(lambda x : convert_to_input_sql(x))
                item_list_dict = df_splited_filter.set_index(['SKU_ID','STATE'])[['PRM_PRICE','CLM_RATE']].to_dict('index')
                for key,value in item_list_dict.items():
                    item_list_dict[key] = [item_list_dict[key]['PRM_PRICE']] + [item_list_dict[key]['CLM_RATE']] 
                    print(item_list_dict)
            # To create excel file
            summary_index_list.append(str(index_promo)+'_'+str(gst))
            # writer_excel_without_remove_rows(df = df_splited,path = path_export_final,cell_export = 'A1',number_sheet=str(index_promo)+'_'+str(gst),path_export_final=path_export_final)   
            pmt_temp = pmt_id[0]
            df_sales = df_sales_data(cursor = cursor,item_list_dict_gsted = item_list_dict,start_date = clm_start,end_date = clm_end, pmt_id_temp = pmt_temp, classify_state= classify_state)
            # print('df_salessssssssssssssssss',df_sales)
            df_item_ref,df_state_ref,df_ref,df_sales,list_data_sales,list_remove_sales  = cd_ref(prmt_id=pmt_temp,cursor = cursor,file_sql=file_sql_cd_ref,item_code=item_list_final,df_sales=df_sales,file_sql_2 = file_sql_cd_ref_listagg , file_sql_3 = file_sql_cd_ref_listagg_item)  
            return df_ref 
            # list_data_state,list_remove_state = product_state_summary(df = df_sales,df_ref=df_ref)
            # list_data_product ,list_remove_product  = product_summary(df = df_sales)
            print('df_salessssssssssssssssss',df_sales)
            list_data_state,list_remove_state = product_state_summary(df = df_sales,df_ref=df_state_ref)
            list_data_product ,list_remove_product  = product_summary(df = df_sales, df_item_ref = df_item_ref)
            dict_data_dept = {'df': f'{int(dept)}E','cell_export':'F8'}
            dict_data_prmt_id = {'df':prmt_id,'cell_export':'B12'}
            dict_data_prmt_name = {'df':prmt_name,'cell_export':'C12'}
            dict_data_paf_loc = {'df':paf_loc,'cell_export':'J4'}
            dict_data_email_loc = {'df':email_loc,'cell_export':'K4'}
            dict_data_supp_num = {'df':int(supp_num),'cell_export':'E8'}
            dict_data_supp_desc = {'df':supp_desc,'cell_export':'C8'}
            dict_data_vendor_num = {'df':vendor_num,'cell_export':'D8'}
            dict_data_claim_number = {'df':str(index_promo)+'_'+str(gst),'cell_export':'B16'}
            list_data = list_data_sales + list_data_state + list_data_product + [dict_data_dept] + [dict_data_prmt_id] + [dict_data_prmt_name] + [dict_data_paf_loc] + [dict_data_email_loc] + [dict_data_supp_num] + [dict_data_supp_desc] + [dict_data_vendor_num] + [dict_data_claim_number]
            list_remove = list_remove_sales + list_remove_state + list_remove_product
            #  Fill sheet Complete Daily Sales Data
            writer_excel(data = list_data, remove = list_remove,number_sheet= str(index_promo)+'_'+str(gst),path_export_final=path_export_final)  
            try:
                insert_attachments(sheet_name = str(index_promo)+'_'+str(gst) ,file_path_excel = paf_loc ,file_path_email = email_loc ,path_export_final = path_export_final)
            except:
                pass
            index_promo+=1
            check_list_promo_index += 1 
            #export check_list_promo
            with xw.App(visible=False) as app:
                print('check_list_promo_index')
                if check_list_promo_index == 2:
                    wb = app.books.open('check_list_promo.xlsx')
                else:
                    wb = app.books.open(path_check_list_promo)
                wb_sheet = wb.sheets['Sheet1']
                check_list_promo = [supp_num] + [supp_desc] +[prmt_id] + [clm_start] + [clm_end]+ [dept] + ['Done'] 
                print(check_list_promo)
                wb_sheet.range(f'A{check_list_promo_index}').value =  check_list_promo
                wb.save(path_check_list_promo)              
        # Fill sheet Vendor Summary
        fill_summary_sheet(summary_index_list= summary_index_list,path_export_final=path_export_final)         
        remove_sheet_change_xlsb(sheet_name = 'template',path_export_final=path_export_final ,path_export_final_xlsb = path_export_final_xlsb)  
        print('-------------------------------------------------------------------------------------------------------------------------------------')
    print(datetime.datetime.now() - time_start)  

if __name__ == '__main__':
    # if not os.path.isdir(fr"D:\\python\\claim_pack_ce\\claim_qty\\{folder_name}"):
    #     os.mkdir(fr"D:\\python\\claim_pack_ce\\claim_qty\\{folder_name}")
    df_ref = main()
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# {Decimal('6022565.00000'): [42963], Decimal('6000635.00000'): [42963], Decimal('8000018.00000'): [42963], Decimal('931859.00000'): [42963], Decimal('632791.00000'): [42963], Decimal('6022537.00000'): [42963]}
#      SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 0   2022-01-28  2022-08-30  2022-01-09  2022-02-02            42963
# 1   2022-05-10  2022-05-10  2022-01-09  2022-02-02            42963
# 2   2022-01-09  2022-08-02  2022-01-09  2022-02-02            42963
# 3   2022-01-29  2022-08-30  2022-01-09  2022-02-02            42963
# 4   2022-01-11  2022-08-28  2022-01-09  2022-02-02            42963
# 5   2022-04-18  2022-04-18  2022-01-09  2022-02-02            42963
# 6   2022-02-21  2022-07-27  2022-01-09  2022-02-02            42963
# 7   2022-08-17  2022-08-17  2022-01-09  2022-02-02            42963
# 8   2022-01-10  2022-08-28  2022-01-09  2022-02-02            42963
# 9   2022-01-09  2022-08-21  2022-01-09  2022-02-02            42963
# 10  2022-01-13  2022-08-28  2022-01-09  2022-02-02            42963
# 11  2022-02-02  2022-02-02  2022-01-09  2022-02-02            42963
#
#    PRMTN_COMP_NAME         SKU_ID                         ITEM_DESC STATE  \
# 0             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML   QLD
# 1             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML    SA
# 2             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML    WA
# 3             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML   VIC
# 4             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML   NSW
# 5             None  5060406080186  MINOR FIGURES COFFEE LATTE 200ML    NT
# 6             None  5060406080209  MINOR FIGURES COFFEE MOCHA 200ML    WA
# 7             None  5060406080209  MINOR FIGURES COFFEE MOCHA 200ML    SA
# 8             None  5060406080209  MINOR FIGURES COFFEE MOCHA 200ML   NSW
# 9             None  5060406080209  MINOR FIGURES COFFEE MOCHA 200ML   QLD
# 10            None  5060406080209  MINOR FIGURES COFFEE MOCHA 200ML   VIC
# 11            None  5060406080605    MINOR FIGURES CHAI LATTE 200ML   VIC
#
#     DEPT_IDNT  ... F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM    ELI ELI_EXCLUDE  \
# 0          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 1          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 2          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 3          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 4          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 5          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 6          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 7          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 8          47  ...               3.64000   -2.00    0E-10  0E-10       0E-10
# 9          47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 10         47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 11         47  ...               1.82000    0.00    0E-10  0E-10       0E-10
#
#    PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT GAP_PROF_PRGX
# 0          None   None         NO           None          None
# 1          None   None         NO           None          None
# 2          None   None         NO           None          None
# 3          None   None         NO           None          None
# 4          None   None         NO           None          None
# 5          None   None         NO           None          None
# 6          None   None         NO           None          None
# 7          None   None         NO           None          None
# 8          None   None         NO           None          None
# 9          None   None         NO           None          None
# 10         None   None         NO           None          None
# 11         None   None         NO           None          None
#
# [12 rows x 29 columns]
#       SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 12   2022-01-24  2022-08-29  2022-01-06  2022-02-11            42963
# 13   2022-01-21  2022-08-14  2022-01-06  2022-02-11            42963
# 14   2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
# 15   2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
# 16   2022-01-06  2022-08-27  2022-01-06  2022-02-11            42963
# ..          ...         ...         ...         ...              ...
# 297  2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
# 298  2022-02-03  2022-08-28  2022-01-06  2022-02-11            42963
# 299  2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
# 300  2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
# 301  2022-01-06  2022-08-30  2022-01-06  2022-02-11            42963
#
#     PRMTN_COMP_NAME         SKU_ID                ITEM_DESC STATE  DEPT_IDNT  \
# 12             None  9300601158805   COLES LITE MILK 2L BTL    NT         47
# 13             None  9300601158805   COLES LITE MILK 2L BTL    WA         47
# 14             None  9300601166930         COLES FC MILK 2L    WA         47
# 15             None  9300601166930         COLES FC MILK 2L    NT         47
# 16             None  9300601186877       COLES LITE MILK 2L   QLD         47
# ..              ...            ...                      ...   ...        ...
# 297            None  9342584073898  OAK CHOCOLATE 600ML CTN   NSW         47
# 298            None  9342584073898  OAK CHOCOLATE 600ML CTN    WA         47
# 299            None  9342584073898  OAK CHOCOLATE 600ML CTN   ACT         47
# 300            None  9342584073898  OAK CHOCOLATE 600ML CTN   QLD         47
# 301            None  9342584073898  OAK CHOCOLATE 600ML CTN   VIC         47
#
#      ... F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM    ELI ELI_EXCLUDE  \
# 12   ...               2.95000    0.00    0E-10  0E-10       0E-10
# 13   ...               2.85000    0.00    0E-10  0E-10       0E-10
# 14   ...               2.95000    0.00    0E-10  0E-10       0E-10
# 15   ...               2.95000    0.00    0E-10  0E-10       0E-10
# 16   ...               2.95000   -1.00    0E-10  0E-10       0E-10
# ..   ...                   ...     ...      ...    ...         ...
# 297  ...               3.86000   -2.00    0E-10  0E-10       0E-10
# 298  ...               3.86000    0.00    0E-10  0E-10       0E-10
# 299  ...               3.86000    0.00    0E-10  0E-10       0E-10
# 300  ...               3.86000   -6.00    0E-10  0E-10       0E-10
# 301  ...               3.86000    0.00    0E-10  0E-10       0E-10
#
#     PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT GAP_PROF_PRGX
# 12          None   None         NO           None          None
# 13          None   None         NO           None          None
# 14          None   None         NO           None          None
# 15          None   None         NO           None          None
# 16          None   None         NO           None          None
# ..           ...    ...        ...            ...           ...
# 297         None   None         NO           None          None
# 298         None   None         NO           None          None
# 299         None   None         NO           None          None
# 300         None   None         NO           None          None
# 301         None   None         NO           None          None
#
# [150 rows x 29 columns]
#       SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 30   2022-01-10  2022-08-23  2022-01-06  2022-02-13            42963
# 31   2022-06-21  2022-08-22  2022-01-06  2022-02-13            42963
# 32   2022-01-29  2022-08-25  2022-01-06  2022-02-13            42963
# 33   2022-01-25  2022-08-29  2022-01-06  2022-02-13            42963
# 34   2022-01-09  2022-08-27  2022-01-06  2022-02-13            42963
# ..          ...         ...         ...         ...              ...
# 278  2022-01-21  2022-05-27  2022-01-06  2022-02-13            42963
# 279  2022-02-04  2022-08-12  2022-01-06  2022-02-13            42963
# 280  2022-02-09  2022-08-27  2022-01-06  2022-02-13            42963
# 281  2022-02-13  2022-08-07  2022-01-06  2022-02-13            42963
# 282  2022-01-27  2022-08-26  2022-01-06  2022-02-13            42963
#
#     PRMTN_COMP_NAME         SKU_ID                      ITEM_DESC STATE  \
# 30             None  9300608614205    DAILY JUICE ORANGE JUICE 2L   QLD
# 31             None  9300608614205    DAILY JUICE ORANGE JUICE 2L    WA
# 32             None  9300608614205    DAILY JUICE ORANGE JUICE 2L    NT
# 33             None  9300608614205    DAILY JUICE ORANGE JUICE 2L   TAS
# 34             None  9300608614205    DAILY JUICE ORANGE JUICE 2L    SA
# ..              ...            ...                            ...   ...
# 278            None  9341650001230  VITASOY WHOLE CHOCOLATE 330ML   NSW
# 279            None  9341650001230  VITASOY WHOLE CHOCOLATE 330ML    WA
# 280            None  9341650001230  VITASOY WHOLE CHOCOLATE 330ML   VIC
# 281            None  9341650001230  VITASOY WHOLE CHOCOLATE 330ML    SA
# 282            None  9341650001230  VITASOY WHOLE CHOCOLATE 330ML   QLD
#
#      DEPT_IDNT  ... F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM    ELI ELI_EXCLUDE  \
# 30          48  ...               5.00000    0.00    0E-10  0E-10       0E-10
# 31          48  ...               5.90000    0.00    0E-10  0E-10       0E-10
# 32          48  ...               5.00000    0.00    0E-10  0E-10       0E-10
# 33          48  ...               5.00000   -1.00    0E-10  0E-10       0E-10
# 34          48  ...               5.00000   -1.00    0E-10  0E-10       0E-10
# ..         ...  ...                   ...     ...      ...    ...         ...
# 278         47  ...               3.73000    0.00    0E-10  0E-10       0E-10
# 279         47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 280         47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 281         47  ...               3.64000    0.00    0E-10  0E-10       0E-10
# 282         47  ...               3.73000    0.00    0E-10  0E-10       0E-10
#
#     PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT GAP_PROF_PRGX
# 30          None   None         NO           None          None
# 31          None   None         NO           None          None
# 32          None   None         NO           None          None
# 33          None   None         NO           None          None
# 34          None   None         NO           None          None
# ..           ...    ...        ...            ...           ...
# 278         None   None         NO           None          None
# 279         None   None         NO           None          None
# 280         None   None         NO           None          None
# 281         None   None         NO           None          None
# 282         None   None         NO           None          None
#
# [135 rows x 29 columns]
#      SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 44  2022-06-21  2022-06-21  2022-01-09  2022-02-25            42963
# 45  2022-08-29  2022-08-29  2022-01-09  2022-02-25            42963
# 46  2022-02-25  2022-02-25  2022-01-09  2022-02-25            42963
# 47  2022-03-07  2022-08-17  2022-01-09  2022-02-25            42963
# 48  2022-01-09  2022-08-18  2022-01-09  2022-02-25            42963
#
#    PRMTN_COMP_NAME         SKU_ID            ITEM_DESC STATE  DEPT_IDNT  ...  \
# 44            None  9300675047661  GLACEAU POWER 500ML    NT         48  ...
# 45            None  9300675057950         SPRITE 250ML   TAS         48  ...
# 46            None  9300675057950         SPRITE 250ML    NT         48  ...
# 47            None  9300675057950         SPRITE 250ML    WA         48  ...
# 48            None  9300675057974          FANTA 250ML    WA         48  ...
#
#    F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM               ELI       ELI_EXCLUDE  \
# 44               1.82000    0.00    0E-10  -5758.9100000000  -5758.9100000000
# 45               1.14000    0.00    0E-10  -5758.9100000000  -5758.9100000000
# 46               1.14000    0.00    0E-10  -5758.9100000000  -5758.9100000000
# 47               1.14000    0.00    0E-10  -5758.9100000000  -5758.9100000000
# 48               1.14000    0.00    0E-10  -5758.9100000000  -5758.9100000000
#
#    PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT GAP_PROF_PRGX
# 44         None   None         NO           None          None
# 45         None   None         NO           None          None
# 46         None   None         NO           None          None
# 47         None   None         NO           None          None
# 48         None   None         NO           None          None
#
# [5 rows x 29 columns]
#       SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 302  2022-01-07  2022-08-13  2022-01-06  2022-02-17            42963
# 303  2022-01-12  2022-07-21  2022-01-06  2022-02-17            42963
# 304  2022-01-15  2022-06-30  2022-01-06  2022-02-17            42963
# 305  2022-01-09  2022-05-14  2022-01-06  2022-02-17            42963
# 306  2022-01-07  2022-08-09  2022-01-06  2022-02-17            42963
# 307  2022-01-06  2022-08-23  2022-01-06  2022-02-17            42963
# 308  2022-01-07  2022-06-01  2022-01-06  2022-02-17            42963
# 309  2022-01-06  2022-02-17  2022-01-06  2022-02-17            42963
# 310  2022-05-27  2022-08-25  2022-01-06  2022-02-17            42963
# 311  2022-01-08  2022-08-30  2022-01-06  2022-02-17            42963
# 312  2022-02-28  2022-08-11  2022-01-06  2022-02-17            42963
# 313  2022-02-09  2022-08-22  2022-01-06  2022-02-17            42963
# 314  2022-02-06  2022-08-19  2022-01-06  2022-02-17            42963
# 315  2022-01-13  2022-08-26  2022-01-06  2022-02-17            42963
# 316  2022-01-11  2022-08-30  2022-01-06  2022-02-17            42963
# 317  2022-04-27  2022-08-25  2022-01-06  2022-02-17            42963
#
#     PRMTN_COMP_NAME         SKU_ID                                ITEM_DESC  \
# 302            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 303            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 304            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 305            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 306            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 307            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 308            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 309            None  9349277001725           BICKFORDS VIOLET CRUMBLE 500ML
# 310            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 311            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 312            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 313            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 314            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 315            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 316            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
# 317            None  9349277001947  VIOLET CRUMBLE CARAMEL FLVRD MILK 500ML
#
#     STATE  DEPT_IDNT  ... F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM    ELI  \
# 302   QLD         47  ...               4.09000    0.00    0E-10  0E-10
# 303   TAS         47  ...               4.09000    0.00    0E-10  0E-10
# 304   ACT         47  ...               4.09000    0.00    0E-10  0E-10
# 305    SA         47  ...               4.09000    0.00    0E-10  0E-10
# 306   VIC         47  ...               4.09000   -1.00    0E-10  0E-10
# 307   NSW         47  ...               4.09000   -1.00    0E-10  0E-10
# 308    WA         47  ...               4.09000    0.00    0E-10  0E-10
# 309    NT         47  ...               4.09000   -2.00    0E-10  0E-10
# 310   ACT         47  ...               4.09000    0.00    0E-10  0E-10
# 311   NSW         47  ...               4.09000   -1.00    0E-10  0E-10
# 312    NT         47  ...               4.09000    0.00    0E-10  0E-10
# 313    WA         47  ...               4.09000    0.00    0E-10  0E-10
# 314   TAS         47  ...               4.09000    0.00    0E-10  0E-10
# 315   QLD         47  ...               4.09000    0.00    0E-10  0E-10
# 316   VIC         47  ...               4.09000    0.00    0E-10  0E-10
# 317    SA         47  ...               4.09000    0.00    0E-10  0E-10
#
#     ELI_EXCLUDE PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT GAP_PROF_PRGX
# 302       0E-10         None   None         NO           None          None
# 303       0E-10         None   None         NO           None          None
# 304       0E-10         None   None         NO           None          None
# 305       0E-10         None   None         NO           None          None
# 306       0E-10         None   None         NO           None          None
# 307       0E-10         None   None         NO           None          None
# 308       0E-10         None   None         NO           None          None
# 309       0E-10         None   None         NO           None          None
# 310       0E-10         None   None         NO           None          None
# 311       0E-10         None   None         NO           None          None
# 312       0E-10         None   None         NO           None          None
# 313       0E-10         None   None         NO           None          None
# 314       0E-10         None   None         NO           None          None
# 315       0E-10         None   None         NO           None          None
# 316       0E-10         None   None         NO           None          None
# 317       0E-10         None   None         NO           None          None
#
# [16 rows x 29 columns]
#       SLS_START     SLS_END   CLM_START     CLM_END  PRMTN_COMP_IDNT  \
# 318  2022-01-27  2022-06-18  2022-01-06  2022-02-03            42963
# 319  2022-02-08  2022-07-31  2022-01-06  2022-02-03            42963
# 320  2022-01-18  2022-05-10  2022-01-06  2022-02-03            42963
# 321  2022-01-07  2022-08-30  2022-01-06  2022-02-03            42963
# 322  2022-03-29  2022-03-29  2022-01-06  2022-02-03            42963
# 323  2022-06-17  2022-06-17  2022-01-06  2022-02-03            42963
# 324  2022-06-06  2022-06-06  2022-01-06  2022-02-03            42963
# 325  2022-01-06  2022-05-02  2022-01-06  2022-02-03            42963
# 326  2022-02-23  2022-06-03  2022-01-06  2022-02-03            42963
# 327  2022-01-06  2022-08-30  2022-01-06  2022-02-03            42963
# 328  2022-01-07  2022-08-19  2022-01-06  2022-02-03            42963
# 329  2022-01-08  2022-08-29  2022-01-06  2022-02-03            42963
# 330  2022-01-07  2022-08-21  2022-01-06  2022-02-03            42963
# 331  2022-01-11  2022-07-26  2022-01-06  2022-02-03            42963
# 332  2022-01-06  2022-08-27  2022-01-06  2022-02-03            42963
# 333  2022-01-18  2022-08-27  2022-01-06  2022-02-03            42963
# 334  2022-01-07  2022-08-26  2022-01-06  2022-02-03            42963
# 335  2022-01-08  2022-08-16  2022-01-06  2022-02-03            42963
# 336  2022-01-12  2022-08-10  2022-01-06  2022-02-03            42963
# 337  2022-01-18  2022-08-20  2022-01-06  2022-02-03            42963
# 338  2022-01-10  2022-08-15  2022-01-06  2022-02-03            42963
# 339  2022-01-06  2022-08-25  2022-01-06  2022-02-03            42963
# 340  2022-02-06  2022-02-11  2022-01-06  2022-02-03            42963
# 341  2022-05-09  2022-07-04  2022-01-06  2022-02-03            42963
# 342  2022-01-07  2022-08-19  2022-01-06  2022-02-03            42963
# 343  2022-02-07  2022-08-28  2022-01-06  2022-02-03            42963
# 344  2022-01-08  2022-08-30  2022-01-06  2022-02-03            42963
# 345  2022-01-07  2022-08-29  2022-01-06  2022-02-03            42963
# 346  2022-01-08  2022-06-09  2022-01-06  2022-02-03            42963
# 347  2022-02-08  2022-07-17  2022-01-06  2022-02-03            42963
# 348  2022-01-09  2022-08-27  2022-01-06  2022-02-03            42963
# 349  2022-03-21  2022-05-08  2022-01-06  2022-02-03            42963
# 350  2022-02-03  2022-02-03  2022-01-06  2022-02-03            42963
# 351  2022-01-17  2022-08-30  2022-01-06  2022-02-03            42963
# 352  2022-01-07  2022-08-21  2022-01-06  2022-02-03            42963
# 353  2022-01-11  2022-08-25  2022-01-06  2022-02-03            42963
# 354  2022-01-08  2022-08-29  2022-01-06  2022-02-03            42963
# 355  2022-03-19  2022-04-22  2022-01-06  2022-02-03            42963
# 356  2022-01-12  2022-08-30  2022-01-06  2022-02-03            42963
# 357  2022-07-04  2022-07-04  2022-01-06  2022-02-03            42963
# 358  2022-01-17  2022-08-17  2022-01-06  2022-02-03            42963
# 359  2022-01-19  2022-07-26  2022-01-06  2022-02-03            42963
# 360  2022-01-18  2022-07-18  2022-01-06  2022-02-03            42963
# 361  2022-01-16  2022-08-04  2022-01-06  2022-02-03            42963
# 362  2022-01-08  2022-08-27  2022-01-06  2022-02-03            42963
# 363  2022-01-10  2022-08-30  2022-01-06  2022-02-03            42963
# 364  2022-03-06  2022-06-21  2022-01-06  2022-02-03            42963
# 365  2022-01-07  2022-08-29  2022-01-06  2022-02-03            42963
# 366  2022-05-01  2022-07-15  2022-01-06  2022-02-03            42963
# 367  2022-05-18  2022-08-28  2022-01-06  2022-02-03            42963
# 368  2022-01-06  2022-08-29  2022-01-06  2022-02-03            42963
# 369  2022-01-23  2022-06-17  2022-01-06  2022-02-03            42963
# 370  2022-06-20  2022-06-28  2022-01-06  2022-02-03            42963
# 371  2022-01-06  2022-08-16  2022-01-06  2022-02-03            42963
# 372  2022-01-11  2022-08-08  2022-01-06  2022-02-03            42963
# 373  2022-08-04  2022-08-04  2022-01-06  2022-02-03            42963
# 374  2022-01-22  2022-07-16  2022-01-06  2022-02-03            42963
# 375  2022-01-12  2022-08-17  2022-01-06  2022-02-03            42963
# 376  2022-01-07  2022-08-22  2022-01-06  2022-02-03            42963
#
#     PRMTN_COMP_NAME         SKU_ID                       ITEM_DESC STATE  \
# 318            None  9352716000203    SHINE TROPICAL COCONUT 330ML    WA
# 319            None  9352716000203    SHINE TROPICAL COCONUT 330ML    SA
# 320            None  9352716000203    SHINE TROPICAL COCONUT 330ML   QLD
# 321            None  9352716000203    SHINE TROPICAL COCONUT 330ML   NSW
# 322            None  9352716000203    SHINE TROPICAL COCONUT 330ML    NT
# 323            None  9352716000203    SHINE TROPICAL COCONUT 330ML   TAS
# 324            None  9352716000203    SHINE TROPICAL COCONUT 330ML   ACT
# 325            None  9352716000203    SHINE TROPICAL COCONUT 330ML   VIC
# 326            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML   TAS
# 327            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML   VIC
# 328            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML   ACT
# 329            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML   NSW
# 330            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML    WA
# 331            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML    SA
# 332            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML   QLD
# 333            None  9352716000210  SHINE PEACH PASSIONFRUIT 330ML    NT
# 334            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML   QLD
# 335            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML    WA
# 336            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML   ACT
# 337            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML    SA
# 338            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML   VIC
# 339            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML   NSW
# 340            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML   TAS
# 341            None  9352716000227  SHINE BLUEBERRY LEMONADE 330ML    NT
# 342            None  9352716000258     SHINE WATERMELON MINT 330ML    WA
# 343            None  9352716000258     SHINE WATERMELON MINT 330ML   ACT
# 344            None  9352716000258     SHINE WATERMELON MINT 330ML   QLD
# 345            None  9352716000258     SHINE WATERMELON MINT 330ML   NSW
# 346            None  9352716000258     SHINE WATERMELON MINT 330ML    NT
# 347            None  9352716000258     SHINE WATERMELON MINT 330ML    SA
# 348            None  9352716000258     SHINE WATERMELON MINT 330ML   VIC
# 349            None  9352716000258     SHINE WATERMELON MINT 330ML   TAS
# 350            None  9352716000265        SHINE ORANGE MANGO 330ML   TAS
# 351            None  9352716000265        SHINE ORANGE MANGO 330ML    WA
# 352            None  9352716000265        SHINE ORANGE MANGO 330ML   QLD
# 353            None  9352716000265        SHINE ORANGE MANGO 330ML   VIC
# 354            None  9352716000265        SHINE ORANGE MANGO 330ML   NSW
# 355            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML    SA
# 356            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML   NSW
# 357            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML    NT
# 358            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML   VIC
# 359            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML   QLD
# 360            None  9352716000814  SHINE PEACH PASSIONFRUIT 250ML    WA
# 361            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML    NT
# 362            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML    WA
# 363            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML   QLD
# 364            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML    SA
# 365            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML   NSW
# 366            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML   TAS
# 367            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML   ACT
# 368            None  9352716000821  SHINE BLUEBERRY LEMONADE 250ML   VIC
# 369            None  9352716000869        SHINE ORANGE MANGO 250ML    SA
# 370            None  9352716000869        SHINE ORANGE MANGO 250ML   TAS
# 371            None  9352716000869        SHINE ORANGE MANGO 250ML   QLD
# 372            None  9352716000869        SHINE ORANGE MANGO 250ML   VIC
# 373            None  9352716000869        SHINE ORANGE MANGO 250ML    NT
# 374            None  9352716000869        SHINE ORANGE MANGO 250ML   ACT
# 375            None  9352716000869        SHINE ORANGE MANGO 250ML   NSW
# 376            None  9352716000869        SHINE ORANGE MANGO 250ML    WA
#
#      DEPT_IDNT  ... F_NORM_SELL_PRICE_AMT VAR_QTY ELI_ITEM               ELI  \
# 318         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 319         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 320         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 321         48  ...               4.50000   -3.00    0E-10  -5758.9100000000
# 322         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 323         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 324         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 325         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 326         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 327         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 328         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 329         48  ...               4.50000   -3.00    0E-10  -5758.9100000000
# 330         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 331         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 332         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 333         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 334         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 335         48  ...               4.50000   -2.00    0E-10  -5758.9100000000
# 336         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 337         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 338         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 339         48  ...               4.50000   -4.00    0E-10  -5758.9100000000
# 340         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 341         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 342         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 343         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 344         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 345         48  ...               4.50000   -2.00    0E-10  -5758.9100000000
# 346         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 347         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 348         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 349         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 350         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 351         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 352         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 353         48  ...               4.50000   -1.00    0E-10  -5758.9100000000
# 354         48  ...               4.50000    0.00    0E-10  -5758.9100000000
# 355         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 356         48  ...               3.59000   -2.00    0E-10  -5758.9100000000
# 357         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 358         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 359         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 360         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 361         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 362         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 363         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 364         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 365         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 366         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 367         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 368         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 369         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 370         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 371         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 372         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 373         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 374         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 375         48  ...               3.59000    0.00    0E-10  -5758.9100000000
# 376         48  ...               3.59000    0.00    0E-10  -5758.9100000000
#
#           ELI_EXCLUDE PAF_LOCATION  EMAIL CHECK_PRGX IDENTIFIED_AMT  \
# 318  -5758.9100000000         None   None         NO           None
# 319  -5758.9100000000         None   None         NO           None
# 320  -5758.9100000000         None   None         NO           None
# 321  -5758.9100000000         None   None         NO           None
# 322  -5758.9100000000         None   None         NO           None
# 323  -5758.9100000000         None   None         NO           None
# 324  -5758.9100000000         None   None         NO           None
# 325  -5758.9100000000         None   None         NO           None
# 326  -5758.9100000000         None   None         NO           None
# 327  -5758.9100000000         None   None         NO           None
# 328  -5758.9100000000         None   None         NO           None
# 329  -5758.9100000000         None   None         NO           None
# 330  -5758.9100000000         None   None         NO           None
# 331  -5758.9100000000         None   None         NO           None
# 332  -5758.9100000000         None   None         NO           None
# 333  -5758.9100000000         None   None         NO           None
# 334  -5758.9100000000         None   None         NO           None
# 335  -5758.9100000000         None   None         NO           None
# 336  -5758.9100000000         None   None         NO           None
# 337  -5758.9100000000         None   None         NO           None
# 338  -5758.9100000000         None   None         NO           None
# 339  -5758.9100000000         None   None         NO           None
# 340  -5758.9100000000         None   None         NO           None
# 341  -5758.9100000000         None   None         NO           None
# 342  -5758.9100000000         None   None         NO           None
# 343  -5758.9100000000         None   None         NO           None
# 344  -5758.9100000000         None   None         NO           None
# 345  -5758.9100000000         None   None         NO           None
# 346  -5758.9100000000         None   None         NO           None
# 347  -5758.9100000000         None   None         NO           None
# 348  -5758.9100000000         None   None         NO           None
# 349  -5758.9100000000         None   None         NO           None
# 350  -5758.9100000000         None   None         NO           None
# 351  -5758.9100000000         None   None         NO           None
# 352  -5758.9100000000         None   None         NO           None
# 353  -5758.9100000000         None   None         NO           None
# 354  -5758.9100000000         None   None         NO           None
# 355  -5758.9100000000         None   None         NO           None
# 356  -5758.9100000000         None   None         NO           None
# 357  -5758.9100000000         None   None         NO           None
# 358  -5758.9100000000         None   None         NO           None
# 359  -5758.9100000000         None   None         NO           None
# 360  -5758.9100000000         None   None         NO           None
# 361  -5758.9100000000         None   None         NO           None
# 362  -5758.9100000000         None   None         NO           None
# 363  -5758.9100000000         None   None         NO           None
# 364  -5758.9100000000         None   None         NO           None
# 365  -5758.9100000000         None   None         NO           None
# 366  -5758.9100000000         None   None         NO           None
# 367  -5758.9100000000         None   None         NO           None
# 368  -5758.9100000000         None   None         NO           None
# 369  -5758.9100000000         None   None         NO           None
# 370  -5758.9100000000         None   None         NO           None
# 371  -5758.9100000000         None   None         NO           None
# 372  -5758.9100000000         None   None         NO           None
# 373  -5758.9100000000         None   None         NO           None
# 374  -5758.9100000000         None   None         NO           None
# 375  -5758.9100000000         None   None         NO           None
# 376  -5758.9100000000         None   None         NO           None
#
#     GAP_PROF_PRGX
# 318          None
# 319          None
# 320          None
# 321          None
# 322          None
# 323          None
# 324          None
# 325          None
# 326          None
# 327          None
# 328          None
# 329          None
# 330          None
# 331          None
# 332          None
# 333          None
# 334          None
# 335          None
# 336          None
# 337          None
# 338          None
# 339          None
# 340          None
# 341          None
# 342          None
# 343          None
# 344          None
# 345          None
# 346          None
# 347          None
# 348          None
# 349          None
# 350          None
# 351          None
# 352          None
# 353          None
# 354          None
# 355          None
# 356          None
# 357          None
# 358          None
# 359          None
# 360          None
# 361          None
# 362          None
# 363          None
# 364          None
# 365          None
# 366          None
# 367          None
# 368          None
# 369          None
# 370          None
# 371          None
# 372          None
# 373          None
# 374          None
# 375          None
# 376          None
#
# [59 rows x 29 columns]
# -------------------------------------------------------42963------------------------------------------------------------------
# supp_desc SHINE DRINK
# 42963
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): {'PRM_PRICE': Decimal('3.53'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): {'PRM_PRICE': Decimal('3.59'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): {'PRM_PRICE': Decimal('3.59'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'ACT'"): {'PRM_PRICE': Decimal('4.32'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'WA'"): {'PRM_PRICE': Decimal('4.39'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'NSW'"): {'PRM_PRICE': Decimal('4.40'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'VIC'"): {'PRM_PRICE': Decimal('4.42'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'QLD'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'NSW'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'QLD'"): {'PRM_PRICE': Decimal('4.44'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'VIC'"): {'PRM_PRICE': Decimal('4.46'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258', "'NSW'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000258', "'VIC'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'VIC'"): {'PRM_PRICE': Decimal('4.48'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): {'PRM_PRICE': Decimal('3.59'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): {'PRM_PRICE': Decimal('3.59'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'ACT'"): {'PRM_PRICE': Decimal('4.32'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'WA'"): {'PRM_PRICE': Decimal('4.39'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'NSW'"): {'PRM_PRICE': Decimal('4.40'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'VIC'"): {'PRM_PRICE': Decimal('4.42'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'QLD'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'NSW'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'QLD'"): {'PRM_PRICE': Decimal('4.44'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'VIC'"): {'PRM_PRICE': Decimal('4.46'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258', "'NSW'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000258', "'VIC'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'VIC'"): {'PRM_PRICE': Decimal('4.48'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): {'PRM_PRICE': Decimal('3.59'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'ACT'"): {'PRM_PRICE': Decimal('4.32'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'WA'"): {'PRM_PRICE': Decimal('4.39'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'NSW'"): {'PRM_PRICE': Decimal('4.40'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'VIC'"): {'PRM_PRICE': Decimal('4.42'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'QLD'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'NSW'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'QLD'"): {'PRM_PRICE': Decimal('4.44'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'VIC'"): {'PRM_PRICE': Decimal('4.46'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258', "'NSW'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000258', "'VIC'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'VIC'"): {'PRM_PRICE': Decimal('4.48'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): {'PRM_PRICE': Decimal('4.32'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'WA'"): {'PRM_PRICE': Decimal('4.39'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'NSW'"): {'PRM_PRICE': Decimal('4.40'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'VIC'"): {'PRM_PRICE': Decimal('4.42'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203', "'QLD'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'NSW'"): {'PRM_PRICE': Decimal('4.43'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'QLD'"): {'PRM_PRICE': Decimal('4.44'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'VIC'"): {'PRM_PRICE': Decimal('4.46'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258', "'NSW'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000258', "'VIC'"): {'PRM_PRICE': Decimal('4.47'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210', "'VIC'"): {'PRM_PRICE': Decimal('4.48'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# ...
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000258,9352716000265', "'QLD'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000258,9352716000265', "'QLD'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000227', "'VIC'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}, ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000258,9352716000265', "'QLD'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000227', "'VIC'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000265', "'NSW'"): {'PRM_PRICE': Decimal('4.50'), 'CLM_RATE': Decimal('0.13000000')}}
# {('9352716000203', "'TAS'"): [Decimal('1.82'), Decimal('0.13000000')], ('9352716000814', "'NSW'"): [Decimal('3.53'), Decimal('0.13000000')], ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000821,9352716000869', "'ACT','NSW','TAS'"): [Decimal('3.59'), Decimal('0.13000000')], ('9352716000210', "'ACT'"): [Decimal('4.32'), Decimal('0.13000000')], ('9352716000227', "'WA'"): [Decimal('4.39'), Decimal('0.13000000')], ('9352716000203', "'NSW'"): [Decimal('4.40'), Decimal('0.13000000')], ('9352716000203', "'VIC'"): [Decimal('4.42'), Decimal('0.13000000')], ('9352716000203', "'QLD'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'NSW'"): [Decimal('4.43'), Decimal('0.13000000')], ('9352716000227', "'QLD'"): [Decimal('4.44'), Decimal('0.13000000')], ('9352716000265', "'VIC'"): [Decimal('4.46'), Decimal('0.13000000')], ('9352716000210,9352716000258', "'NSW'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000258', "'VIC'"): [Decimal('4.47'), Decimal('0.13000000')], ('9352716000210', "'VIC'"): [Decimal('4.48'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000203,9352716000227,9352716000258', "'ACT'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000210,9352716000258,9352716000265', "'QLD'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000227', "'VIC'"): [Decimal('4.50'), Decimal('0.13000000')], ('9352716000265', "'NSW'"): [Decimal('4.50'), Decimal('0.13000000')]}
# TO QA_STATE
# ('9352716000203', "'TAS'") [Decimal('1.82'), Decimal('0.13000000')]
# ('9352716000814', "'NSW'") [Decimal('3.53'), Decimal('0.13000000')]
# ('9352716000814,9352716000821,9352716000869', "'NT','QLD','SA','VIC','WA'") [Decimal('3.59'), Decimal('0.13000000')]
# ('9352716000821,9352716000869', "'ACT','NSW','TAS'") [Decimal('3.59'), Decimal('0.13000000')]
# ('9352716000210', "'ACT'") [Decimal('4.32'), Decimal('0.13000000')]
# ('9352716000227', "'WA'") [Decimal('4.39'), Decimal('0.13000000')]
# ('9352716000203', "'NSW'") [Decimal('4.40'), Decimal('0.13000000')]
# ('9352716000203', "'VIC'") [Decimal('4.42'), Decimal('0.13000000')]
# ('9352716000203', "'QLD'") [Decimal('4.43'), Decimal('0.13000000')]
# ('9352716000227', "'NSW'") [Decimal('4.43'), Decimal('0.13000000')]
# ('9352716000227', "'QLD'") [Decimal('4.44'), Decimal('0.13000000')]
# ('9352716000265', "'VIC'") [Decimal('4.46'), Decimal('0.13000000')]
# ('9352716000210,9352716000258', "'NSW'") [Decimal('4.47'), Decimal('0.13000000')]
# ('9352716000258', "'VIC'") [Decimal('4.47'), Decimal('0.13000000')]
# ('9352716000210', "'VIC'") [Decimal('4.48'), Decimal('0.13000000')]
# ('9352716000203,9352716000210,9352716000227,9352716000258', "'NT','SA'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000203,9352716000210,9352716000258,9352716000265', "'WA'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000203,9352716000227,9352716000258', "'ACT'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000210,9352716000227,9352716000258,9352716000265', "'TAS'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000210,9352716000258,9352716000265', "'QLD'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000227', "'VIC'") [Decimal('4.50'), Decimal('0.13000000')]
# ('9352716000265', "'NSW'") [Decimal('4.50'), Decimal('0.13000000')]
# Start cd ref
# item_code '9352716000203','9352716000210','9352716000227','9352716000258','9352716000265','9352716000814','9352716000821','9352716000869'
# prmt_id 42963
# df_ref_groupby:
#  Empty DataFrame
# Columns: [CLM_REF_NUM, CLM_PRODUCT]
# Index: []
# Done cd ref
# start state ref
# Empty DataFrame
# Columns: [ITEM_IDNT, CLM_STATE, CLM_QTY, CLM_RATE, CLM_PRODUCT, REF_NUM]
# Index: []
# done state ref
# start item ref
# Empty DataFrame
# Columns: [ITEM_IDNT, CLM_QTY, CLM_RATE, CLM_PRODUCT, REF_NUM]
# Index: []
# done item ref

# %%
try:
    df_ref_groupby = df_ref.groupby('CLM_REF_NUM').agg({'CLM_PRODUCT':'sum'}).sort_values(by='CLM_PRODUCT', ascending=True).reset_index()
except:
    df_ref_groupby = pd.DataFrame(columns=['CLM_REF_NUM','CLM_PRODUCT'])
df_ref_groupby
# Out:
# Empty DataFrame
# Columns: [CLM_REF_NUM, CLM_PRODUCT]
# Index: []
